# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 44 (delta 16), reused 32 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 72.99 KiB | 12.16 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 9.3 MB/s eta 0:00:00

# %%
# !python ptbxl-ssl-objectives/train_reconstruction.py mask 71
# Out:
# ssl_method: mask
# seed: 71
# device: cuda
# out_dir: mask_seed71
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'mask', 'train_loss': 0.08730627280952287, 'lr': 4.2630769077121856e-05}
# {'epoch': 2, 'ssl_method': 'mask', 'train_loss': 0.03272651700153403, 'lr': 5.0494239033749386e-05}
# {'epoch': 3, 'ssl_method': 'mask', 'train_loss': 0.026173019156295017, 'lr': 6.350421414654634e-05}
# {'epoch': 4, 'ssl_method': 'mask', 'train_loss': 0.02431575571914224, 'lr': 8.15180850812586e-05}
# {'epoch': 5, 'ssl_method': 'mask', 'train_loss': 0.023574118563619843, 'lr': 0.00010433839211032678}
# {'epoch': 6, 'ssl_method': 'mask', 'train_loss': 0.023230234065847677, 'lr': 0.00013171498957515718}
# {'epoch': 7, 'ssl_method': 'mask', 'train_loss': 0.022795743098224165, 'lr': 0.00016334778786721927}
# ...

# %%
# !zip -r mask_seed71.zip mask_seed71
# !du -sh mask_seed71.zip
# Out:
#   adding: mask_seed71/ (stored 0%)
#   adding: mask_seed71/finetune_head/ (stored 0%)
#   adding: mask_seed71/finetune_head/100pct/ (stored 0%)
#   adding: mask_seed71/finetune_head/100pct/train_subset_indices.npy (deflated 81%)
#   adding: mask_seed71/finetune_head/100pct/val_preds.npy (deflated 6%)
#   adding: mask_seed71/finetune_head/100pct/test_preds.npy (deflated 6%)
#   adding: mask_seed71/finetune_head/100pct/test_per_class_auc.npy (deflated 18%)
#   adding: mask_seed71/finetune_head/100pct/metrics.json (deflated 43%)
#   adding: mask_seed71/finetune_head/100pct/history.csv (deflated 60%)
#   adding: mask_seed71/finetune_head/100pct/val_per_class_auc.npy (deflated 18%)
#   adding: mask_seed71/finetune_head/100pct/best_model.pt (deflated 9%)
#   adding: mask_seed71/finetune_head/001pct/ (stored 0%)
#   adding: mask_seed71/finetune_head/001pct/train_subset_indices.npy (deflated 68%)
#   adding: mask_seed71/finetune_head/001pct/val_preds.npy (deflated 9%)
# ...
