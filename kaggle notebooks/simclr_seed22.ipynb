# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 29 (delta 10), reused 25 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 21.89 KiB | 5.47 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 4.2 MB/s eta 0:00:0000:01

# %%
# !python ptbxl-ssl-objectives/train_contrastive_simclr.py 22
# Out:
# ssl_method: simclr
# seed: 22
# device: cuda
# out_dir: simclr_seed22
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'simclr', 'train_loss': 5.176410629468806, 'lr': 4.2630778483913174e-05}
# {'epoch': 2, 'ssl_method': 'simclr', 'train_loss': 5.123107584083781, 'lr': 5.049427645468878e-05}
# {'epoch': 3, 'ssl_method': 'simclr', 'train_loss': 5.071848760632908, 'lr': 6.350429757370204e-05}
# {'epoch': 4, 'ssl_method': 'simclr', 'train_loss': 4.960742406985339, 'lr': 8.151823149247378e-05}
# {'epoch': 5, 'ssl_method': 'simclr', 'train_loss': 4.790867801974802, 'lr': 0.00010433861708698626}
# {'epoch': 6, 'ssl_method': 'simclr', 'train_loss': 4.507270616643569, 'lr': 0.0001317153069430036}
# {'epoch': 7, 'ssl_method': 'simclr', 'train_loss': 4.131529964068356, 'lr': 0.00016334820936621762}
# ...

# %%
# !zip -r simclr_seed22.zip simclr_seed22
# !du -sh simclr_seed22.zip
# Out:
#   adding: simclr_seed22/ (stored 0%)
#   adding: simclr_seed22/finetune_head/ (stored 0%)
#   adding: simclr_seed22/finetune_head/010pct/ (stored 0%)
#   adding: simclr_seed22/finetune_head/010pct/test_preds.npy (deflated 7%)
#   adding: simclr_seed22/finetune_head/010pct/best_model.pt (deflated 9%)
#   adding: simclr_seed22/finetune_head/010pct/test_per_class_auc.npy (deflated 18%)
#   adding: simclr_seed22/finetune_head/010pct/metrics.json (deflated 44%)
#   adding: simclr_seed22/finetune_head/010pct/val_preds.npy (deflated 7%)
#   adding: simclr_seed22/finetune_head/010pct/val_per_class_auc.npy (deflated 18%)
#   adding: simclr_seed22/finetune_head/010pct/history.csv (deflated 60%)
#   adding: simclr_seed22/finetune_head/010pct/train_subset_indices.npy (deflated 79%)
#   adding: simclr_seed22/finetune_head/025pct/ (stored 0%)
#   adding: simclr_seed22/finetune_head/025pct/test_preds.npy (deflated 7%)
#   adding: simclr_seed22/finetune_head/025pct/best_model.pt (deflated 9%)
# ...
