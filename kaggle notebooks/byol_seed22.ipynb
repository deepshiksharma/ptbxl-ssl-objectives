# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 29 (delta 10), reused 25 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 21.89 KiB | 3.65 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 3.4 MB/s eta 0:00:0000:01

# %%
# !python ptbxl-ssl-objectives/train_contrastive_byol.py 22
# Out:
# ssl_method: byol
# seed: 22
# device: cuda
# out_dir: byol_seed22
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'byol', 'train_loss': 1.538344005451483, 'lr': 4.2630778483913174e-05}
# {'epoch': 2, 'ssl_method': 'byol', 'train_loss': 0.6751359718687394, 'lr': 5.049427645468878e-05}
# {'epoch': 3, 'ssl_method': 'byol', 'train_loss': 0.18551316638203227, 'lr': 6.350429757370204e-05}
# {'epoch': 4, 'ssl_method': 'byol', 'train_loss': 0.10226658907006769, 'lr': 8.151823149247378e-05}
# {'epoch': 5, 'ssl_method': 'byol', 'train_loss': 0.1081338288152919, 'lr': 0.00010433861708698626}
# {'epoch': 6, 'ssl_method': 'byol', 'train_loss': 0.13232354206197403, 'lr': 0.0001317153069430036}
# {'epoch': 7, 'ssl_method': 'byol', 'train_loss': 0.15761084460160313, 'lr': 0.00016334820936621762}
# ...

# %%
# !zip -r byol_seed22.zip byol_seed22
# !du -sh byol_seed22.zip
# Out:
#   adding: byol_seed22/ (stored 0%)
#   adding: byol_seed22/finetune_head/ (stored 0%)
#   adding: byol_seed22/finetune_head/001pct/ (stored 0%)
#   adding: byol_seed22/finetune_head/001pct/metrics.json (deflated 44%)
#   adding: byol_seed22/finetune_head/001pct/history.csv (deflated 60%)
#   adding: byol_seed22/finetune_head/001pct/test_preds.npy (deflated 10%)
#   adding: byol_seed22/finetune_head/001pct/val_preds.npy (deflated 10%)
#   adding: byol_seed22/finetune_head/001pct/train_subset_indices.npy (deflated 68%)
#   adding: byol_seed22/finetune_head/001pct/val_per_class_auc.npy (deflated 18%)
#   adding: byol_seed22/finetune_head/001pct/test_per_class_auc.npy (deflated 18%)
#   adding: byol_seed22/finetune_head/001pct/best_model.pt (deflated 9%)
#   adding: byol_seed22/finetune_head/025pct/ (stored 0%)
#   adding: byol_seed22/finetune_head/025pct/metrics.json (deflated 43%)
#   adding: byol_seed22/finetune_head/025pct/history.csv (deflated 60%)
# ...
