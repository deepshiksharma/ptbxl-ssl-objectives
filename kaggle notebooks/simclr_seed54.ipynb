# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 44 (delta 16), reused 32 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 72.99 KiB | 2.70 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 3.9 MB/s eta 0:00:0000:01

# %%
# !python ptbxl-ssl-objectives/train_contrastive_simclr.py 54
# Out:
# ssl_method: simclr
# seed: 54
# device: cuda
# out_dir: simclr_seed54
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'simclr', 'train_loss': 5.180076932205873, 'lr': 4.2630778483913174e-05}
# {'epoch': 2, 'ssl_method': 'simclr', 'train_loss': 5.116583761046915, 'lr': 5.049427645468878e-05}
# {'epoch': 3, 'ssl_method': 'simclr', 'train_loss': 5.074218588716843, 'lr': 6.350429757370204e-05}
# {'epoch': 4, 'ssl_method': 'simclr', 'train_loss': 4.965820547412424, 'lr': 8.151823149247378e-05}
# {'epoch': 5, 'ssl_method': 'simclr', 'train_loss': 4.81029889162849, 'lr': 0.00010433861708698626}
# {'epoch': 6, 'ssl_method': 'simclr', 'train_loss': 4.542929270688226, 'lr': 0.0001317153069430036}
# {'epoch': 7, 'ssl_method': 'simclr', 'train_loss': 4.159258016768624, 'lr': 0.00016334820936621762}
# ...

# %%
# !zip -r simclr_seed54.zip simclr_seed54
# !du -sh simclr_seed54.zip
# Out:
#   adding: simclr_seed54/ (stored 0%)
#   adding: simclr_seed54/finetune_head/ (stored 0%)
#   adding: simclr_seed54/finetune_head/025pct/ (stored 0%)
#   adding: simclr_seed54/finetune_head/025pct/metrics.json (deflated 44%)
#   adding: simclr_seed54/finetune_head/025pct/train_subset_indices.npy (deflated 80%)
#   adding: simclr_seed54/finetune_head/025pct/history.csv (deflated 60%)
#   adding: simclr_seed54/finetune_head/025pct/test_per_class_auc.npy (deflated 18%)
#   adding: simclr_seed54/finetune_head/025pct/best_model.pt (deflated 9%)
#   adding: simclr_seed54/finetune_head/025pct/val_preds.npy (deflated 7%)
#   adding: simclr_seed54/finetune_head/025pct/test_preds.npy (deflated 7%)
#   adding: simclr_seed54/finetune_head/025pct/val_per_class_auc.npy (deflated 17%)
#   adding: simclr_seed54/finetune_head/100pct/ (stored 0%)
#   adding: simclr_seed54/finetune_head/100pct/metrics.json (deflated 44%)
# ...
