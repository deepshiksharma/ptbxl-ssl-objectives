# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 44 (delta 16), reused 32 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 72.99 KiB | 8.11 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 6.6 MB/s eta 0:00:00

# %%
# !python ptbxl-ssl-objectives/train_reconstruction.py denoise 71
# Out:
# ssl_method: denoise
# seed: 71
# device: cuda
# out_dir: denoise_seed71
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'denoise', 'train_loss': 0.09607508229295703, 'lr': 4.2630769077121856e-05}
# {'epoch': 2, 'ssl_method': 'denoise', 'train_loss': 0.03039376267714657, 'lr': 5.0494239033749386e-05}
# {'epoch': 3, 'ssl_method': 'denoise', 'train_loss': 0.025409273150628502, 'lr': 6.350421414654634e-05}
# {'epoch': 4, 'ssl_method': 'denoise', 'train_loss': 0.024108579980522175, 'lr': 8.15180850812586e-05}
# {'epoch': 5, 'ssl_method': 'denoise', 'train_loss': 0.023190931355866203, 'lr': 0.00010433839211032678}
# {'epoch': 6, 'ssl_method': 'denoise', 'train_loss': 0.02286846212444514, 'lr': 0.00013171498957515718}
# {'epoch': 7, 'ssl_method': 'denoise', 'train_loss': 0.022375548734282054, 'lr': 0.00016334778786721927}
# ...

# %%
# !zip -r denoise_seed71.zip denoise_seed71
# !du -sh denoise_seed71.zip
# Out:
#   adding: denoise_seed71/ (stored 0%)
#   adding: denoise_seed71/all_metrics.json (deflated 85%)
#   adding: denoise_seed71/config.json (deflated 51%)
#   adding: denoise_seed71/pretrain/ (stored 0%)
#   adding: denoise_seed71/pretrain/pretrain_last.pt (deflated 10%)
#   adding: denoise_seed71/pretrain/pretrain_history.csv (deflated 58%)
#   adding: denoise_seed71/finetune_head/ (stored 0%)
#   adding: denoise_seed71/finetune_head/025pct/ (stored 0%)
#   adding: denoise_seed71/finetune_head/025pct/val_preds.npy (deflated 8%)
#   adding: denoise_seed71/finetune_head/025pct/metrics.json (deflated 44%)
#   adding: denoise_seed71/finetune_head/025pct/test_preds.npy (deflated 8%)
#   adding: denoise_seed71/finetune_head/025pct/history.csv (deflated 59%)
#   adding: denoise_seed71/finetune_head/025pct/best_model.pt (deflated 9%)
#   adding: denoise_seed71/finetune_head/025pct/train_subset_indices.npy (deflated 80%)
# ...
