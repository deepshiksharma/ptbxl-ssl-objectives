# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 29 (delta 10), reused 25 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 21.89 KiB | 5.47 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 5.0 MB/s eta 0:00:00

# %%
# !python ptbxl-ssl-objectives/train_reconstruction.py mask 22
# Out:
# ssl_method: mask
# seed: 22
# device: cuda
# out_dir: mask_seed22
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'mask', 'train_loss': 0.10131337257088537, 'lr': 4.2630769077121856e-05}
# {'epoch': 2, 'ssl_method': 'mask', 'train_loss': 0.03624221560184973, 'lr': 5.0494239033749386e-05}
# {'epoch': 3, 'ssl_method': 'mask', 'train_loss': 0.02726285723819785, 'lr': 6.350421414654634e-05}
# {'epoch': 4, 'ssl_method': 'mask', 'train_loss': 0.02464977385353868, 'lr': 8.15180850812586e-05}
# {'epoch': 5, 'ssl_method': 'mask', 'train_loss': 0.023747817674366227, 'lr': 0.00010433839211032678}
# {'epoch': 6, 'ssl_method': 'mask', 'train_loss': 0.02342003696754466, 'lr': 0.00013171498957515718}
# {'epoch': 7, 'ssl_method': 'mask', 'train_loss': 0.023047223156929888, 'lr': 0.00016334778786721927}
# ...

# %%
# !zip -r mask_seed22.zip mask_seed22
# !du -sh mask_seed22.zip
# Out:
#   adding: mask_seed22/ (stored 0%)
#   adding: mask_seed22/all_metrics.json (deflated 85%)
#   adding: mask_seed22/finetune_head/ (stored 0%)
#   adding: mask_seed22/finetune_head/005pct/ (stored 0%)
#   adding: mask_seed22/finetune_head/005pct/val_per_class_auc.npy (deflated 18%)
#   adding: mask_seed22/finetune_head/005pct/test_per_class_auc.npy (deflated 18%)
#   adding: mask_seed22/finetune_head/005pct/test_preds.npy (deflated 8%)
#   adding: mask_seed22/finetune_head/005pct/metrics.json (deflated 43%)
#   adding: mask_seed22/finetune_head/005pct/train_subset_indices.npy (deflated 78%)
#   adding: mask_seed22/finetune_head/005pct/best_model.pt (deflated 9%)
#   adding: mask_seed22/finetune_head/005pct/history.csv (deflated 59%)
#   adding: mask_seed22/finetune_head/005pct/val_preds.npy (deflated 8%)
#   adding: mask_seed22/finetune_head/001pct/ (stored 0%)
#   adding: mask_seed22/finetune_head/001pct/val_per_class_auc.npy (deflated 17%)
# ...
