# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 44 (delta 16), reused 32 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 72.99 KiB | 10.43 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 5.9 MB/s eta 0:00:00

# %%
# !python ptbxl-ssl-objectives/train_contrastive_simclr.py 71
# Out:
# ssl_method: simclr
# seed: 71
# device: cuda
# out_dir: simclr_seed71
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'simclr', 'train_loss': 5.161787138265722, 'lr': 4.2630778483913174e-05}
# {'epoch': 2, 'ssl_method': 'simclr', 'train_loss': 5.098141403759227, 'lr': 5.049427645468878e-05}
# {'epoch': 3, 'ssl_method': 'simclr', 'train_loss': 5.055134534835815, 'lr': 6.350429757370204e-05}
# {'epoch': 4, 'ssl_method': 'simclr', 'train_loss': 4.915725508156945, 'lr': 8.151823149247378e-05}
# {'epoch': 5, 'ssl_method': 'simclr', 'train_loss': 4.742969600593343, 'lr': 0.00010433861708698626}
# {'epoch': 6, 'ssl_method': 'simclr', 'train_loss': 4.4846472389557785, 'lr': 0.0001317153069430036}
# {'epoch': 7, 'ssl_method': 'simclr', 'train_loss': 4.1648215072996475, 'lr': 0.00016334820936621762}
# ...

# %%
# !zip -r simclr_seed71.zip simclr_seed71
# !du -sh simclr_seed71.zip
# Out:
#   adding: simclr_seed71/ (stored 0%)
#   adding: simclr_seed71/finetune_full/ (stored 0%)
#   adding: simclr_seed71/finetune_full/001pct/ (stored 0%)
#   adding: simclr_seed71/finetune_full/001pct/val_per_class_auc.npy (deflated 18%)
#   adding: simclr_seed71/finetune_full/001pct/test_per_class_auc.npy (deflated 17%)
#   adding: simclr_seed71/finetune_full/001pct/train_subset_indices.npy (deflated 68%)
#   adding: simclr_seed71/finetune_full/001pct/best_model.pt (deflated 9%)
#   adding: simclr_seed71/finetune_full/001pct/test_preds.npy (deflated 12%)
#   adding: simclr_seed71/finetune_full/001pct/metrics.json (deflated 44%)
#   adding: simclr_seed71/finetune_full/001pct/val_preds.npy (deflated 12%)
#   adding: simclr_seed71/finetune_full/001pct/history.csv (deflated 60%)
#   adding: simclr_seed71/finetune_full/005pct/ (stored 0%)
#   adding: simclr_seed71/finetune_full/005pct/val_per_class_auc.npy (deflated 18%)
# ...
