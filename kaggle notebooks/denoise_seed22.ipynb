# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 29 (delta 10), reused 25 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 21.89 KiB | 5.47 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 6.4 MB/s eta 0:00:00

# %%
# !python ptbxl-ssl-objectives/train_reconstruction.py denoise 22
# Out:
# ssl_method: denoise
# seed: 22
# device: cuda
# out_dir: denoise_seed22
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'denoise', 'train_loss': 0.11762778683953042, 'lr': 4.2630769077121856e-05}
# {'epoch': 2, 'ssl_method': 'denoise', 'train_loss': 0.03733103791673253, 'lr': 5.0494239033749386e-05}
# {'epoch': 3, 'ssl_method': 'denoise', 'train_loss': 0.026424722895570046, 'lr': 6.350421414654634e-05}
# {'epoch': 4, 'ssl_method': 'denoise', 'train_loss': 0.023819648885052568, 'lr': 8.15180850812586e-05}
# {'epoch': 5, 'ssl_method': 'denoise', 'train_loss': 0.023226464982994282, 'lr': 0.00010433839211032678}
# {'epoch': 6, 'ssl_method': 'denoise', 'train_loss': 0.022834847756002072, 'lr': 0.00013171498957515718}
# {'epoch': 7, 'ssl_method': 'denoise', 'train_loss': 0.022484316918862997, 'lr': 0.00016334778786721927}
# ...

# %%
# !zip -r denoise_seed22.zip denoise_seed22
# !du -sh denoise_seed22.zip
# Out:
#   adding: denoise_seed22/ (stored 0%)
#   adding: denoise_seed22/config.json (deflated 52%)
#   adding: denoise_seed22/finetune_full/ (stored 0%)
#   adding: denoise_seed22/finetune_full/010pct/ (stored 0%)
#   adding: denoise_seed22/finetune_full/010pct/best_model.pt (deflated 9%)
#   adding: denoise_seed22/finetune_full/010pct/val_preds.npy (deflated 11%)
#   adding: denoise_seed22/finetune_full/010pct/train_subset_indices.npy (deflated 79%)
#   adding: denoise_seed22/finetune_full/010pct/metrics.json (deflated 44%)
#   adding: denoise_seed22/finetune_full/010pct/val_per_class_auc.npy (deflated 17%)
#   adding: denoise_seed22/finetune_full/010pct/test_per_class_auc.npy (deflated 18%)
#   adding: denoise_seed22/finetune_full/010pct/history.csv (deflated 60%)
#   adding: denoise_seed22/finetune_full/010pct/test_preds.npy (deflated 11%)
#   adding: denoise_seed22/finetune_full/025pct/ (stored 0%)
#   adding: denoise_seed22/finetune_full/025pct/best_model.pt (deflated 9%)
# ...
