# %%
# !git clone https://github.com/deepshiksharma/ptbxl-ssl-objectives.git
# !pip install -q wfdb
# Out:
# Cloning into 'ptbxl-ssl-objectives'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 44 (delta 16), reused 32 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 72.99 KiB | 6.63 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 6.7 MB/s eta 0:00:00

# %%
# !python ptbxl-ssl-objectives/train_reconstruction.py mask 54
# Out:
# ssl_method: mask
# seed: 54
# device: cuda
# out_dir: mask_seed54
# x: (21837, 1000, 12)
# y: (21837, 44)
# train: (17441, 1000, 12) (17441, 44)
# val: (2193, 1000, 12) (2193, 44)
# test: (2203, 1000, 12) (2203, 44)
# num_classes: 44
# {'epoch': 1, 'ssl_method': 'mask', 'train_loss': 0.09532889778161571, 'lr': 4.2630769077121856e-05}
# {'epoch': 2, 'ssl_method': 'mask', 'train_loss': 0.03380177896061953, 'lr': 5.0494239033749386e-05}
# {'epoch': 3, 'ssl_method': 'mask', 'train_loss': 0.02633969907234185, 'lr': 6.350421414654634e-05}
# {'epoch': 4, 'ssl_method': 'mask', 'train_loss': 0.02449277909404605, 'lr': 8.15180850812586e-05}
# {'epoch': 5, 'ssl_method': 'mask', 'train_loss': 0.023519148723813738, 'lr': 0.00010433839211032678}
# {'epoch': 6, 'ssl_method': 'mask', 'train_loss': 0.023387961184782702, 'lr': 0.00013171498957515718}
# {'epoch': 7, 'ssl_method': 'mask', 'train_loss': 0.023017840133640017, 'lr': 0.00016334778786721927}
# ...

# %%
# !zip -r mask_seed54.zip mask_seed54
# !du -sh mask_seed54.zip
# Out:
#   adding: mask_seed54/ (stored 0%)
#   adding: mask_seed54/config.json (deflated 51%)
#   adding: mask_seed54/pretrain/ (stored 0%)
#   adding: mask_seed54/pretrain/pretrain_history.csv (deflated 56%)
#   adding: mask_seed54/pretrain/pretrain_last.pt (deflated 10%)
#   adding: mask_seed54/finetune_full/ (stored 0%)
#   adding: mask_seed54/finetune_full/001pct/ (stored 0%)
#   adding: mask_seed54/finetune_full/001pct/test_preds.npy (deflated 13%)
#   adding: mask_seed54/finetune_full/001pct/test_per_class_auc.npy (deflated 17%)
#   adding: mask_seed54/finetune_full/001pct/val_per_class_auc.npy (deflated 18%)
#   adding: mask_seed54/finetune_full/001pct/train_subset_indices.npy (deflated 68%)
#   adding: mask_seed54/finetune_full/001pct/history.csv (deflated 60%)
#   adding: mask_seed54/finetune_full/001pct/val_preds.npy (deflated 13%)
#   adding: mask_seed54/finetune_full/001pct/best_model.pt (deflated 9%)
#   adding: mask_seed54/finetune_full/001pct/metrics.json (deflated 43%)
# ...
